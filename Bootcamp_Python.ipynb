# %% [markdown]
# <a href="https://colab.research.google.com/github/ngminhdao/kedge_bootcamp/blob/main/Bootcamp_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bootcamp Python

# %%
ma_variable = 8

# %%
ma_variable
# Out:
# 8

# %%
print(ma_variable)
# Out:
# 8
