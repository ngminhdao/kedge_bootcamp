# %% [markdown]
# <a href="https://colab.research.google.com/github/ngminhdao/kedge_bootcamp/blob/main/1_session_apprenant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **String**

# %%
"boris"
# Out:
# 'boris'

# %%
"boris".capitalize()

# %%
"   boris ".strip()

# %% [markdown]
# **Exercice 1/4 :**
#
# créé une variable avec ton prénom et affiche le.

# %%
mon_prenom = "Minh-Dao"
print(mon_prenom)
# Out:
# Minh-Dao

# %%
mon_prenom
# Out:
# 'Minh-Dao'

# %%
type(mon_prenom)
# Out:
# str

# %%
message_saisi = input()

print(type(message_saisi))
# Out:
# 2
# <class 'str'>

# %% [markdown]
# **Exercice 2/4 :**
#
# 1. Utiliser ces 3 méthodes pour obtenir les résultats suivants :
#
# alix -> Alix
#
# 2. ce message doit être en majuscule :
#
# sherlock holmes -> Sherlock Holmes
#
# Utiliser l'une ou plusieurs des méthodes ci-dessous :
#
# texte.upper()
# texte.lower()
# texte.capitalize()

# %%
from typing import Concatenate
prenom1 = "alix"
print(prenom1.capitalize())

message_saisi = input()
liste_mots = message_saisi.strip().split(sep = " ")
final = ""
for i in range(0,len(liste_mots)) :
  final = final + liste_mots[i].capitalize() + " "
print(final.strip())
# Out:
# Alix
#   everything everywhere all at once
# Everything Everywhere All At Once

# %% [markdown]
# **Exercice 3/4 :**
#
# Concaténation
#
# prenom = "Cédric"
# nom = "Dupont"
# metier = "Ingénieur"
#
# phrase = "Bonjour, je m'appelle " + prenom + " " + nom + " et je suis " + metier + "."
#
#
# print(phrase)
#
# print("Bonjour, je m'appelle " + prenom + nom)
#
#
# print("Bonjour, je m'appelle " + prenom.lower() + " " + nom.upper() + ".")

# %%
prenom = "Minh-Dao"
nom = "Nguyen"
metier = "analyste des données"

phrase = "Bonjour, je m'appelle " + prenom + " " + nom + " et je suis " + metier + "."

print(phrase)
# Out:
# Bonjour, je m'appelle Minh-Dao Nguyen et je suis analyste.

# %% [markdown]
# **Exercice 4/4 :**
#
# f-string
#
# print(f"Bonjour, je m'appelle {prenom} {nom} et je suis {metier}.")
#
# prenom = "  "
# age =
# ville = "   "
#
# Dans une nouvelle celulle, essaye cette commande et tente de comprendre le fonctionnement :
#
# print(f"Bonjour, je m'appelle {prenom}, j'ai {age} ans et j'habite à {ville}.")

# %% [markdown]
# Ensuite, essaye de résoudre cette demande avec ce que tu as appris :
#
# prenom = "Béatrice"
#
# age = 23
#
# "Dans 5 ans, Béatrice aura  ans."

# %%
prenom = "Béatrice"

age = 23

print("Entrez un nombre entier : ")

saisi = input()

age_futur = age + int(saisi)

print(f"Dans 5 ans, {prenom} aura {age_futur} ans.")
# Out:
# Entrez un nombre entier :
# 10
# Dans 5 ans, Béatrice aura 33 ans.

# %% [markdown]
# **Numeric Type**

# %%
type(42)

# %%
type(3.14)

# %%
4 + 9.5

# %%
nombre = 76

# %% [markdown]
# **Exercice 1/2 :**
#
# Créé une variable avec ton âge et affiche le.

# %%
mon_age = 30
print(mon_age)
# Out:
# 30

# %% [markdown]
# **Exercice 2/2 :**
#
# Calcul la moyenne à partir de ces notes : 9, 11, 17, 14.5, 10

# %%
import statistics

liste_num = [9,11,17,14.5,10]
print(type(liste_num))
moyen = statistics.mean(liste_num)
print(moyen)
# Out:
# <class 'list'>
# 12.3

# %% [markdown]
# **Booleans**

# %%
5>7
# Out:
# False

# %%
"Kedge" == "kedge"

# %%
"KEDGE" == "kedge".upper()

# %%
"KEDGE" != "kedge".upper()

# %% [markdown]
# **Opérateurs logiques**
#
# and
#
# or
#
# not

# %% [markdown]
# Produire 3 scripts :
#
# 1. **Compter les caractères**
#
# Objectif
#
# Créer un script qui demande à l’utilisateur de saisir un texte, puis affiche le nombre de caractères saisis.
#
# Pistes pour l’apprenant
#
# 	•	Commence par récupérer une saisie utilisateur.
#
# 	•	Stocke cette saisie dans une variable.
#
# 	•	Utilise une fonction intégrée qui permet de connaître la taille d’un texte.
#
# 	•	Affiche le résultat avec print() (tu peux utiliser une f-string).
#
# 2. **Convertisseur Celsius FAHRENHEIT**
#
# Objectif
#
# Créer un script qui convertit une température en Celsius vers Fahrenheit.
#
# Formule à utiliser
#
# F = (C × 9/5) + 32
#
# Pistes pour l’apprenant
#
# 	•	Demande une température en Celsius à l’utilisateur.
#
# 	•	Attention : une température peut être décimale, donc il faut convertir la saisie dans le bon type.
#
# 	•	Applique la formule dans une nouvelle variable.
#
# 	•	Affiche clairement le résultat (avec les unités °C et °F).
#
#
# 3. **Calculer une moyenne en la tronquant**
#
# Objectif
#
# Créer un script qui demande 3 notes, calcule la moyenne, puis affiche la moyenne tronquée (sans décimales, sans arrondir).
#
# Pistes pour l’apprenant
#
# 	•	Demande 3 valeurs numériques à l’utilisateur.
#
# 	•	Convertis les saisies dans un type numérique.
#
# 	•	Calcule la moyenne avec une formule simple.
#
# 	•	Affiche :
# 	•	la moyenne “normale”
# 	•	puis la moyenne tronquée
#
# 	•	Pour tronquer, utilise une fonction / conversion qui supprime les décimales sans arrondir.

# %%
print("Script 1 : Compter les caractères")

print("Veuillez saisir une texte: ")

message_saisi = input()

nb_char = len(message_saisi)

print(f"Votre texte a {nb_char} caractères.")
# Out:
# Script 1 : Compter les caractères
# Veuillez saisir une texte:
# sherlock holmes
# Votre texte a 15 caractères.

# %%
print("Script 2: Convertisseur Celsius FAHRENHEIT")

print("Veuillez saisir la température en celsius: ")

saisi = input()
celsius = float(saisi)
fahrenheit = (celsius*9/5) + 32

print(f"La température en Fahrenheit est {fahrenheit}.")
# Out:
# Script 2: Convertisseur Celsius FAHRENHEIT
# Veuillez saisir la température en celsius:
# 15
# La température en Fahrenheit est 59.0.

# %%
print("Script 3: Calculer la moyenne en tronquant")

print("Veuillez entre 3 notes:")
note1 = float(input())
note2 = float(input())
note3 = float(input())

moyen = (note1 + note2 + note3)/3
moyen_tronque = int(moyen)

print(f"La moyenne normale des 3 notes est {moyen}.")
print(f"La moyenne tronquée des 3 notes est {moyen_tronque}.")
# Out:
# Script 3: Calculer la moyenne en tronquant
# Veuillez entre 3 notes:
# 7
# 12
# 10
# La moyenne normale des 3 notes est 9.666666666666666.
# La moyenne tronquée des 3 notes est 9.

# %% [markdown]
# **Listes**

# %%
["apple", "cherries", "banana"]

# %%
len(["apple", "cherries", "banana"])

# %%
"banana" in ["apple", "cherries", "banana"]

# %%
list = ["apple", "cherries", "banana"]
print(list)

# %%
liste_nom_section_2 = [
    "Salma AJANNY",
    "Morgane AMICHIA",
    "Sasha AMMAR",
    "Anne ANGODO",
    "Yasmine BENAYAD",
    "Hugo BLASUTTO",
    "Oumaïma BOULAHOUAL",
    "Zineb BOUSSEBTI",
    "Léa BUATOIS",
    "François CAILLET",
    "Thibaut DA SILVA ROCHA",
    "Matthieu DEMUSSY",
    "Pierre DIEU",
    "Caroline DUCHENNE",
    "Israe el kentaoui",
    "Anas Elbeidaq",
    "Hermann ELOMBAT",
    "Naomie FATAKI",
    "Etienne GALZIN",
    "Maud GOLVEN",
    "Lucie HONDAREYTE",
    "Ibtissam Hammouti",
    "Nadine JAZIRI",
    "Saoussane KERKASS",
    "Belle-Ange KOKATE RODONGO",
    "Zakaria lakdim",
    "Manon LEONARD",
    "Jacques LONG",
    "Keven MAUNG",
    "Clara MAYON",
    "Anas MOUAZAOUI",
    "Noura NATEK",
    "Minh-Dao NGUYEN",
    "Jules PADRUTT",
    "Youssef SAAD",
    "Enzo SATOUGLÉ-DEFITH",
    "Emma SERRAI",
    "Wissal TAKNANI",
    "Lou TRAZIÉ",
    "Oumou YADE"
]

# %%
list1 = [3, "Terre", ["pomme", "banane", "fraise"]]
print(list1[-1])
# Out:
# ['pomme', 'banane', 'fraise']

# %% [markdown]
# Créé une liste avec tes hobbies.

# %%
mes_hobbies = ["Jeux vidéos", "Lecture"]
print(mes_hobbies)
# Out:
# ['Jeux vidéos', 'Lecture']

# %% [markdown]
# **Conditions**

# %%
age = int(input("How old are you?"))

if age >= 21:
    print("You can become president")
elif age >= 18:
    print("You can vote")
else:
    print("Be patient!")
# Out:
# How old are you?30
# You can become president

# %% [markdown]
# 1. Développer un jeu où votre voisin doit deviner un nombre compris entre 1 et 10.

# %% [markdown]
# 2. Développer un jeu où votre voisin doit deviner un nombre compris entre 1 et 100. Vous devez lui donner des indices (exemple : "le nombre recherché est plus petit" ou "le nombre recherché est plus grand")

# %% [markdown]
# Utiliser la documentation : https://docs.python.org/fr/3/library/random.html#random.randint

# %%
import random

print(random.random())

print(random.randint(1,100))
# Out:
# 0.4421886938393472
# 72

# %%
import random as r

result = r.randint(1,100)

devine = 0

while True :
  try:
    while devine != result:
      devine = int(input("Devine un nombre compris entre 1 et 100 : "))
      if devine < result:
        print("Le nombre recherché est plus grand.")
      else:
        if devine > result:
          print("Le nombre recherché est plus petit.")
        else: print("Tu as trouvé le nombre!")
  except:
    print("Pas un nombre entier. Essaie encore une fois.")
  else:
    break
# Out:
# Devine un nombre compris entre 1 et 100 : 20
# Le nombre recherché est plus petit.
# Devine un nombre compris entre 1 et 100 : 15
# Le nombre recherché est plus grand.
# Devine un nombre compris entre 1 et 100 : 18
# Le nombre recherché est plus petit.
# Devine un nombre compris entre 1 et 100 : 17
# Tu as trouvé le nombre!

# %% [markdown]
# Développer un jeu de pile ou face

# %%
guess = ""
correct = 0
streak = 0
total = 0

cont = True

while cont:
  print("Pile (P) ou Face (F)? (Tape N pour arreter)")
  while (guess != "P") and (guess != "F") and (guess != "N"):
    guess = input()
  if guess == "N" : cont = False
  results = r.randint(0,1)
  total += 1
  if results == 0 :
    print("Pile!")
    if guess == "P":
      correct += 1
      streak += 1
      print(f"Tu l'as eu! Nb correct: {correct}. Streak: {streak}. Taux de succès: {(correct/total*100):.2f}%.")
    if guess == "F":
      streak = 0
      print(f"Meilleure chance la prochaine fois. Nb correct: {correct}. Streak: {streak}. Taux de succès: {(correct/total*100):.2f}%.")
  if results == 1 :
    print("Face!")
    if guess == "F":
      correct += 1
      streak += 1
      print(f"Tu l'as eu! Nb correct: {correct}. Streak: {streak}. Taux de succès: {(correct/total*100):.2f}%.")
    if guess == "P":
      streak = 0
      print(f"Meilleure chance la prochaine fois. Nb correct: {correct}. Streak: {streak}. Taux de succès: {(correct/total*100):.2f}%.")
  guess = ""
  print("F")
# Out:
# Pile (P) ou Face (F)? (Tape N pour arreter)
# P
# Face!
# Meilleure chance la prochaine fois. Nb correct: 0. Streak: 0. Taux de succès: 0.00%.
#
# Pile (P) ou Face (F)? (Tape N pour arreter)
# P
# Face!
# Meilleure chance la prochaine fois. Nb correct: 0. Streak: 0. Taux de succès: 0.00%.
#
# Pile (P) ou Face (F)? (Tape N pour arreter)
# P
# Face!
# Meilleure chance la prochaine fois. Nb correct: 0. Streak: 0. Taux de succès: 0.00%.
#
# Pile (P) ou Face (F)? (Tape N pour arreter)
# F
# Pile!
# Meilleure chance la prochaine fois. Nb correct: 0. Streak: 0. Taux de succès: 0.00%.
#
# Pile (P) ou Face (F)? (Tape N pour arreter)
# F
# Face!
# Tu l'as eu! Nb correct: 1. Streak: 1. Taux de succès: 20.00%.
#
# Pile (P) ou Face (F)? (Tape N pour arreter)
# F
# Face!
# Tu l'as eu! Nb correct: 2. Streak: 2. Taux de succès: 33.33%.
#
# Pile (P) ou Face (F)? (Tape N pour arreter)
# P
# Pile!
# Tu l'as eu! Nb correct: 3. Streak: 3. Taux de succès: 42.86%.
#
# ...

# %% [markdown]
# Le jeu oppose deux joueurs.
# Chaque joueur choisit en secret l’un des trois symboles :
#
# 🪨 Pierre
#
# 📄 Feuille
#
# ✂️ Ciseau
#
# Une fois les deux choix effectués, on compare pour déterminer le gagnant.
#
# ⚖️ Règles du jeu
#
# Chaque symbole bat un autre symbole :
#
# Pierre bat ✂️ Ciseau
#
# Feuille bat 🪨 Pierre
#
# Ciseau bat 📄 Feuille
#
# Si les deux joueurs choisissent le même symbole, il y a égalité.
#
# Méthode
#
# Trouver un système simple :
#
# Demander le choix du joueur 1
#
# Demander le choix du joueur 2
#
# Comparer les deux choix
#
#
# Afficher le résultat

# %%
guess = ""
correct = 0
streak = 0
total = 0

cont = True

while cont:
  print("Pierre (P) ou Feuille (F) ou Ciseau (C)? (Tape N pour arreter)")
  while (guess != "P") and (guess != "F") and (guess != "C") and (guess != "N"):
    guess = input()
  if guess == "N" : cont = False
  results = r.randint(0,2)
  total += 1
  if results == 0 :
    print("La machine choisit : Pierre!")
    if guess == "F":
      correct += 1
      streak += 1
      print(f"Tu l'as eu avec Feuille! Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
    if guess == "C":
      streak = 0
      print(f"Ciseau, c'est perdu. Meilleure chance la prochaine fois. Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
    if guess == "P":
      print(f"C'est l'égalité. Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
  if results == 1 :
    print("La machine choisit : Feuille!")
    if guess == "C":
      correct += 1
      streak += 1
      print(f"Tu l'as eu avec Ciseau! Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
    if guess == "P":
      streak = 0
      print(f"Pierre, c'est perdu. Meilleure chance la prochaine fois. Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
    if guess == "F":
      print(f"C'est l'égalité. Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
  if results == 2 :
    print("La machine choisit : Ciseau!")
    if guess == "P":
      correct += 1
      streak += 1
      print(f"Tu l'as eu avec Pierre! Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
    if guess == "F":
      streak = 0
      print(f"Feuille, c'est perdu. Meilleure chance la prochaine fois. Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
    if guess == "C":
      print(f"C'est l'égalité. Nb victoire: {correct}. Streak: {streak}. Taux de victoire: {(correct/total*100):.2f}%.")
  guess = ""
  print("")
# Out:
# Pierre (P) ou Feuille (F) ou Ciseau (C)? (Tape N pour arreter)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3196057993.py in <cell line: 0>()
#       9   print("Pierre (P) ou Feuille (F) ou Ciseau (C)? (Tape N pour arreter)")
#      10   while (guess != "P") and (guess != "F") and (guess != "C") and (guess != "N"):
# ---> 11     guess = input()
#      12   if guess == "N" : cont = False
#      13   results = r.randint(0,2)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
